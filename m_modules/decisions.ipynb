# %%
'''This is for recording code and plots that guide decisions made in the project.'''

# %%
'''decided not to fourier approximate quadratic error. Approximated quadratic error corrected prediction instead'''

# %% [markdown]
# ### putting some previous plots here for reference
# $\lambda^b$
# ![image.png](attachment:image.png)
#
# $\lambda^{lambda*b}$
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## With n = 7/3;
#  global $\lambda = 7$ correction with $e^{\lambda * a}$ in amplitude. The 2nd plot suggests we should predict from N2.
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ## With n = 2;
#  global $\lambda = 7$ correction with $e^{\lambda * a}$ in amplitude.
#  ![image-5.png](attachment:image-5.png)
#  ![image-6.png](attachment:image-6.png)
#  ![image-4.png](attachment:image-4.png)
#  ![image-3.png](attachment:image-3.png)
#  ![image-2.png](attachment:image-2.png)
#  ![image.png](attachment:image.png)
